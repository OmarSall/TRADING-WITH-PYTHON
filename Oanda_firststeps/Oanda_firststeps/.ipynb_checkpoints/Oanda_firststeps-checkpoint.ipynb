# %% [markdown]
# # First Steps with the OANDA API

# %% [markdown]
# ## Connecting to the API / Server

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
#available methods and attributes

api.get_account_summary()
# Out:
# {'id': '101-012-23109564-001',
#  'alias': 'Primary',
#  'currency': 'EUR',
#  'balance': '51084.9692',
#  'createdByUserID': 23109564,
#  'createdTime': '2022-08-29T12:03:45.377934162Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '1088.8734',
#  'resettablePL': '1088.8734',
#  'resettablePLTime': '0',
#  'financing': '-3.9042',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.02',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '51084.9692',
#  'marginUsed': '0.0',
#  'marginAvailable': '51084.9692',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '51084.9692',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '51084.9692',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '19'}

# %%
api.account_type
# Out:
# 'practice'

# %%
api.account_id
# Out:
# '101-012-23109564-001'

# %%
api.get_instruments()
# Out:
# [('Copper', 'XCU_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('USD/NOK', 'USD_NOK'),
#  ('UK 100', 'UK100_GBP'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('Silver', 'XAG_USD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Litecoin', 'LTC_USD'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('NZD/USD', 'NZD_USD'),
#  ('USD/CNH', 'USD_CNH'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('ZAR/JPY', 'ZAR_JPY'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Ether', 'ETH_USD'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('USD/JPY', 'USD_JPY'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('Bitcoin', 'BTC_USD'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('Taiwan Index', 'TWIX_USD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('USD/THB', 'USD_THB'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('USD/TRY', 'USD_TRY'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('USD/SGD', 'USD_SGD'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Corn', 'CORN_USD'),
#  ('USD/PLN', 'USD_PLN'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('USD/INR', 'USD_INR'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('USD/DKK', 'USD_DKK'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Japan 225', 'JP225_USD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('USD/CZK', 'USD_CZK'),
#  ('China A50', 'CN50_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/MXN', 'USD_MXN'),
#  ('GBP/USD', 'GBP_USD'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('Gold', 'XAU_USD'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('US Wall St 30', 'US30_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('Sugar', 'SUGAR_USD'),
#  ('AUD/CAD', 'AUD_CAD'),
#  ('USD/HKD', 'USD_HKD'),
#  ('CAD/SGD', 'CAD_SGD')]

# %%
instr = api.get_instruments()

# %%
len(instr)
# Out:
# 129

# %%
instr[0]
# Out:
# ('Copper', 'XCU_USD')

# %% [markdown]
# ## Getting Historical Data (Part 1)

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
#     ==========
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask) or 'B' (bid)
#
#     Returns
#     =======
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-31",
                granularity = "D", price = "B")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   90252      True  1.12293  1.12744  1.11837
# 2020-07-01 21:00:00+00:00   90789      True  1.12501  1.13020  1.12188
# 2020-07-02 21:00:00+00:00   59036      True  1.12384  1.12492  1.12186
# 2020-07-05 21:00:00+00:00   81756      True  1.12423  1.13449  1.12391
# 2020-07-06 21:00:00+00:00   92426      True  1.13070  1.13318  1.12581
# 2020-07-07 21:00:00+00:00   89549      True  1.12717  1.13505  1.12615
# 2020-07-08 21:00:00+00:00  104729      True  1.13287  1.13699  1.12774
# 2020-07-09 21:00:00+00:00   81510      True  1.12808  1.13242  1.12540
# 2020-07-12 21:00:00+00:00   86512      True  1.13042  1.13744  1.13002
# 2020-07-13 21:00:00+00:00  106478      True  1.13420  1.14081  1.13232
# 2020-07-14 21:00:00+00:00  100308      True  1.13979  1.14512  1.13901
# 2020-07-15 21:00:00+00:00  102144      True  1.14108  1.14411  1.13698
# 2020-07-16 21:00:00+00:00   73024      True  1.13827  1.14432  1.13737
# 2020-07-19 21:00:00+00:00  104209      True  1.14088  1.14672  1.14017
# 2020-07-20 21:00:00+00:00  111043      True  1.14461  1.15391  1.14223
# 2020-07-21 21:00:00+00:00  129890      True  1.15257  1.16009  1.15059
# 2020-07-22 21:00:00+00:00  115345      True  1.15634  1.16260  1.15397
# 2020-07-23 21:00:00+00:00  115447      True  1.15920  1.16571  1.15806
# 2020-07-26 21:00:00+00:00  123653      True  1.16420  1.17809  1.16387
# 2020-07-27 21:00:00+00:00  126006      True  1.17502  1.17729  1.16980
# 2020-07-28 21:00:00+00:00  121087      True  1.17145  1.18054  1.17114
# 2020-07-29 21:00:00+00:00  128163      True  1.17904  1.18475  1.17304
# 2020-07-30 21:00:00+00:00  154943      True  1.18465  1.19081  1.17602
#
#                                  c
# time
# 2020-06-30 21:00:00+00:00  1.12501
# 2020-07-01 21:00:00+00:00  1.12384
# 2020-07-02 21:00:00+00:00  1.12429
# 2020-07-05 21:00:00+00:00  1.13076
# 2020-07-06 21:00:00+00:00  1.12726
# 2020-07-07 21:00:00+00:00  1.13287
# 2020-07-08 21:00:00+00:00  1.12837
# 2020-07-09 21:00:00+00:00  1.12977
# 2020-07-12 21:00:00+00:00  1.13420
# 2020-07-13 21:00:00+00:00  1.13985
# 2020-07-14 21:00:00+00:00  1.14108
# 2020-07-15 21:00:00+00:00  1.13827
# 2020-07-16 21:00:00+00:00  1.14252
# 2020-07-19 21:00:00+00:00  1.14461
# 2020-07-20 21:00:00+00:00  1.15257
# 2020-07-21 21:00:00+00:00  1.15687
# 2020-07-22 21:00:00+00:00  1.15952
# 2020-07-23 21:00:00+00:00  1.16540
# 2020-07-26 21:00:00+00:00  1.17502
# 2020-07-27 21:00:00+00:00  1.17138
# 2020-07-28 21:00:00+00:00  1.17904
# 2020-07-29 21:00:00+00:00  1.18465
# 2020-07-30 21:00:00+00:00  1.17751

# %%
df = api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-31",
                granularity = "D", price = "B")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23 entries, 2020-06-30 21:00:00+00:00 to 2020-07-30 21:00:00+00:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   volume    23 non-null     int64
#  1   complete  23 non-null     bool
#  2   o         23 non-null     float64
#  3   h         23 non-null     float64
#  4   l         23 non-null     float64
#  5   c         23 non-null     float64
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 1.1 KB

# %%
api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-01",
                granularity = "D", price = "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   90252      True  1.12393  1.12758  1.11858
#
#                                  c
# time
# 2020-06-30 21:00:00+00:00  1.12527

# %%
api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-01",
                granularity = "D", price = "B")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   90252      True  1.12293  1.12744  1.11837
#
#                                  c
# time
# 2020-06-30 21:00:00+00:00  1.12501

# %% [markdown]
# ## Getting Historical Data (Part 2)

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-05", "H1", "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-08-03 00:00:00+00:00    6315      True  1.17821  1.17900  1.17418
# 2020-08-03 01:00:00+00:00    4786      True  1.17544  1.17732  1.17461
# 2020-08-03 02:00:00+00:00    2092      True  1.17720  1.17744  1.17638
# 2020-08-03 03:00:00+00:00    1561      True  1.17693  1.17768  1.17672
# 2020-08-03 04:00:00+00:00    1496      True  1.17739  1.17832  1.17722
# 2020-08-03 05:00:00+00:00    1959      True  1.17767  1.17799  1.17678
# 2020-08-03 06:00:00+00:00    5793      True  1.17748  1.17762  1.17495
# 2020-08-03 07:00:00+00:00    9003      True  1.17510  1.17687  1.17506
# 2020-08-03 08:00:00+00:00    8002      True  1.17632  1.17857  1.17601
# 2020-08-03 09:00:00+00:00    6627      True  1.17799  1.17804  1.17430
# 2020-08-03 10:00:00+00:00    7682      True  1.17451  1.17460  1.17149
# 2020-08-03 11:00:00+00:00    5557      True  1.17258  1.17354  1.17254
# 2020-08-03 12:00:00+00:00    7233      True  1.17259  1.17350  1.17068
# 2020-08-03 13:00:00+00:00    9396      True  1.17084  1.17250  1.16966
# 2020-08-03 14:00:00+00:00   11324      True  1.17240  1.17441  1.17224
# 2020-08-03 15:00:00+00:00    6837      True  1.17388  1.17514  1.17342
# 2020-08-03 16:00:00+00:00    3956      True  1.17503  1.17528  1.17390
# 2020-08-03 17:00:00+00:00    3572      True  1.17498  1.17593  1.17477
# 2020-08-03 18:00:00+00:00    3120      True  1.17526  1.17642  1.17516
# 2020-08-03 19:00:00+00:00    2793      True  1.17596  1.17666  1.17587
# 2020-08-03 20:00:00+00:00    1166      True  1.17648  1.17687  1.17630
# 2020-08-03 21:00:00+00:00     175      True  1.17632  1.17699  1.17618
# 2020-08-03 22:00:00+00:00     416      True  1.17629  1.17693  1.17603
# 2020-08-03 23:00:00+00:00     559      True  1.17615  1.17618  1.17569
# 2020-08-04 00:00:00+00:00    1472      True  1.17609  1.17624  1.17529
# 2020-08-04 01:00:00+00:00    1610      True  1.17546  1.17602  1.17540
# 2020-08-04 02:00:00+00:00    1475      True  1.17590  1.17741  1.17577
# 2020-08-04 03:00:00+00:00    1386      True  1.17729  1.17748  1.17642
# 2020-08-04 04:00:00+00:00    1169      True  1.17687  1.17754  1.17678
# 2020-08-04 05:00:00+00:00    1617      True  1.17746  1.17781  1.17648
# 2020-08-04 06:00:00+00:00    5409      True  1.17677  1.17809  1.17649
# 2020-08-04 07:00:00+00:00   11029      True  1.17780  1.18034  1.17725
# 2020-08-04 08:00:00+00:00    9091      True  1.17872  1.17959  1.17736
# 2020-08-04 09:00:00+00:00    7353      True  1.17933  1.18071  1.17928
# 2020-08-04 10:00:00+00:00    7140      True  1.17955  1.17961  1.17687
# 2020-08-04 11:00:00+00:00    7599      True  1.17709  1.17741  1.17553
# 2020-08-04 12:00:00+00:00   10370      True  1.17618  1.17719  1.17229
# 2020-08-04 13:00:00+00:00   10603      True  1.17291  1.17389  1.17221
# 2020-08-04 14:00:00+00:00   11371      True  1.17256  1.17652  1.17249
# 2020-08-04 15:00:00+00:00    7072      True  1.17574  1.17744  1.17514
# 2020-08-04 16:00:00+00:00    5020      True  1.17658  1.17785  1.17653
# 2020-08-04 17:00:00+00:00    3868      True  1.17784  1.17860  1.17767
# 2020-08-04 18:00:00+00:00    3394      True  1.17834  1.17924  1.17753
# 2020-08-04 19:00:00+00:00    3615      True  1.17828  1.18038  1.17827
# 2020-08-04 20:00:00+00:00    1088      True  1.18037  1.18043  1.17953
# 2020-08-04 21:00:00+00:00      53      True  1.18063  1.18063  1.17984
# 2020-08-04 22:00:00+00:00     675      True  1.17984  1.18013  1.17937
# 2020-08-04 23:00:00+00:00     897      True  1.17992  1.18161  1.17954
#
#                                  c
# time
# 2020-08-03 00:00:00+00:00  1.17543
# 2020-08-03 01:00:00+00:00  1.17722
# 2020-08-03 02:00:00+00:00  1.17691
# 2020-08-03 03:00:00+00:00  1.17741
# 2020-08-03 04:00:00+00:00  1.17770
# 2020-08-03 05:00:00+00:00  1.17746
# 2020-08-03 06:00:00+00:00  1.17508
# 2020-08-03 07:00:00+00:00  1.17631
# 2020-08-03 08:00:00+00:00  1.17798
# 2020-08-03 09:00:00+00:00  1.17452
# 2020-08-03 10:00:00+00:00  1.17257
# 2020-08-03 11:00:00+00:00  1.17260
# 2020-08-03 12:00:00+00:00  1.17083
# 2020-08-03 13:00:00+00:00  1.17241
# 2020-08-03 14:00:00+00:00  1.17388
# 2020-08-03 15:00:00+00:00  1.17504
# 2020-08-03 16:00:00+00:00  1.17499
# 2020-08-03 17:00:00+00:00  1.17526
# 2020-08-03 18:00:00+00:00  1.17598
# 2020-08-03 19:00:00+00:00  1.17649
# 2020-08-03 20:00:00+00:00  1.17632
# 2020-08-03 21:00:00+00:00  1.17639
# 2020-08-03 22:00:00+00:00  1.17613
# 2020-08-03 23:00:00+00:00  1.17611
# 2020-08-04 00:00:00+00:00  1.17545
# 2020-08-04 01:00:00+00:00  1.17592
# 2020-08-04 02:00:00+00:00  1.17730
# 2020-08-04 03:00:00+00:00  1.17686
# 2020-08-04 04:00:00+00:00  1.17747
# 2020-08-04 05:00:00+00:00  1.17675
# 2020-08-04 06:00:00+00:00  1.17777
# 2020-08-04 07:00:00+00:00  1.17874
# 2020-08-04 08:00:00+00:00  1.17936
# 2020-08-04 09:00:00+00:00  1.17955
# 2020-08-04 10:00:00+00:00  1.17708
# 2020-08-04 11:00:00+00:00  1.17620
# 2020-08-04 12:00:00+00:00  1.17290
# 2020-08-04 13:00:00+00:00  1.17254
# 2020-08-04 14:00:00+00:00  1.17573
# 2020-08-04 15:00:00+00:00  1.17659
# 2020-08-04 16:00:00+00:00  1.17785
# 2020-08-04 17:00:00+00:00  1.17835
# 2020-08-04 18:00:00+00:00  1.17830
# 2020-08-04 19:00:00+00:00  1.18033
# 2020-08-04 20:00:00+00:00  1.18040
# 2020-08-04 21:00:00+00:00  1.17989
# 2020-08-04 22:00:00+00:00  1.17990
# 2020-08-04 23:00:00+00:00  1.18148

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-05", "H12", "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-08-02 21:00:00+00:00   43624      True  1.17828  1.17976  1.17418
# 2020-08-03 09:00:00+00:00   69263      True  1.17799  1.17804  1.16966
# 2020-08-03 21:00:00+00:00   35408      True  1.17632  1.18034  1.17529
# 2020-08-04 09:00:00+00:00   78493      True  1.17933  1.18071  1.17221
# 2020-08-04 21:00:00+00:00   33438      True  1.18063  1.18421  1.17937
#
#                                  c
# time
# 2020-08-02 21:00:00+00:00  1.17798
# 2020-08-03 09:00:00+00:00  1.17632
# 2020-08-03 21:00:00+00:00  1.17936
# 2020-08-04 09:00:00+00:00  1.18040
# 2020-08-04 21:00:00+00:00  1.18408

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-05", "M1", "A")
# Out:
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
#                            volume  complete        o        h        l  \
# time
# 2020-08-03 00:00:00+00:00      44      True  1.17821  1.17835  1.17819
# 2020-08-03 00:01:00+00:00      59      True  1.17835  1.17871  1.17833
# 2020-08-03 00:02:00+00:00      62      True  1.17873  1.17896  1.17873
# 2020-08-03 00:03:00+00:00      36      True  1.17885  1.17900  1.17877
# 2020-08-03 00:04:00+00:00      64      True  1.17877  1.17877  1.17824
# ...                           ...       ...      ...      ...      ...
# 2020-08-04 23:55:00+00:00     129      True  1.18098  1.18161  1.18096
# 2020-08-04 23:56:00+00:00      28      True  1.18149  1.18161  1.18146
# 2020-08-04 23:57:00+00:00      23      True  1.18156  1.18160  1.18152
# 2020-08-04 23:58:00+00:00      15      True  1.18154  1.18161  1.18148
# 2020-08-04 23:59:00+00:00      11      True  1.18153  1.18155  1.18147
#
#                                  c
# time
# 2020-08-03 00:00:00+00:00  1.17835
# 2020-08-03 00:01:00+00:00  1.17871
# 2020-08-03 00:02:00+00:00  1.17884
# 2020-08-03 00:03:00+00:00  1.17877
# 2020-08-03 00:04:00+00:00  1.17835
# ...                            ...
# 2020-08-04 23:55:00+00:00  1.18147
# 2020-08-04 23:56:00+00:00  1.18159
# 2020-08-04 23:57:00+00:00  1.18156
# 2020-08-04 23:58:00+00:00  1.18155
# 2020-08-04 23:59:00+00:00  1.18148
#
# [2803 rows x 6 columns]

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-04", "S5", "A")
# Out:
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
# C:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\tpqoa\tpqoa.py:161: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(batch)
#                            volume  complete        o        h        l  \
# time
# 2020-08-03 00:00:00+00:00      16      True  1.17821  1.17830  1.17819
# 2020-08-03 00:00:10+00:00       6      True  1.17827  1.17832  1.17824
# 2020-08-03 00:00:15+00:00       7      True  1.17830  1.17830  1.17823
# 2020-08-03 00:00:30+00:00       4      True  1.17829  1.17830  1.17828
# 2020-08-03 00:00:35+00:00       1      True  1.17827  1.17827  1.17827
# ...                           ...       ...      ...      ...      ...
# 2020-08-03 23:57:20+00:00       1      True  1.17608  1.17608  1.17608
# 2020-08-03 23:57:50+00:00       3      True  1.17609  1.17613  1.17609
# 2020-08-03 23:58:35+00:00       1      True  1.17613  1.17613  1.17613
# 2020-08-03 23:59:45+00:00       2      True  1.17613  1.17613  1.17611
# 2020-08-03 23:59:50+00:00       2      True  1.17609  1.17611  1.17609
#
#                                  c
# time
# 2020-08-03 00:00:00+00:00  1.17828
# 2020-08-03 00:00:10+00:00  1.17832
# 2020-08-03 00:00:15+00:00  1.17826
# 2020-08-03 00:00:30+00:00  1.17829
# 2020-08-03 00:00:35+00:00  1.17827
# ...                            ...
# 2020-08-03 23:57:20+00:00  1.17608
# 2020-08-03 23:57:50+00:00  1.17613
# 2020-08-03 23:58:35+00:00  1.17613
# 2020-08-03 23:59:45+00:00  1.17611
# 2020-08-03 23:59:50+00:00  1.17611
#
# [13561 rows x 6 columns]

# %%
api.get_instruments()
# Out:
# [('Copper', 'XCU_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('USD/NOK', 'USD_NOK'),
#  ('UK 100', 'UK100_GBP'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('Silver', 'XAG_USD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Litecoin', 'LTC_USD'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('NZD/USD', 'NZD_USD'),
#  ('USD/CNH', 'USD_CNH'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('ZAR/JPY', 'ZAR_JPY'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Ether', 'ETH_USD'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('USD/JPY', 'USD_JPY'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('Bitcoin', 'BTC_USD'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('Taiwan Index', 'TWIX_USD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('USD/THB', 'USD_THB'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('USD/TRY', 'USD_TRY'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('USD/SGD', 'USD_SGD'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Corn', 'CORN_USD'),
#  ('USD/PLN', 'USD_PLN'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('USD/INR', 'USD_INR'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('USD/DKK', 'USD_DKK'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Japan 225', 'JP225_USD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('USD/CZK', 'USD_CZK'),
#  ('China A50', 'CN50_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/MXN', 'USD_MXN'),
#  ('GBP/USD', 'GBP_USD'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('Gold', 'XAU_USD'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('US Wall St 30', 'US30_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('Sugar', 'SUGAR_USD'),
#  ('AUD/CAD', 'AUD_CAD'),
#  ('USD/HKD', 'USD_HKD'),
#  ('CAD/SGD', 'CAD_SGD')]

# %%
api.get_history("SPX500_USD", "2020-08-03", "2020-08-04", "H1", "A")
# Out:
#                            volume  complete       o       h       l       c
# time
# 2020-08-03 00:00:00+00:00    2094      True  3272.8  3276.1  3267.0  3273.5
# 2020-08-03 01:00:00+00:00    1916      True  3273.8  3279.6  3271.5  3277.8
# 2020-08-03 02:00:00+00:00     843      True  3278.1  3278.1  3270.5  3271.8
# 2020-08-03 03:00:00+00:00     482      True  3272.3  3273.8  3269.5  3270.3
# 2020-08-03 04:00:00+00:00     368      True  3270.6  3271.8  3268.5  3271.8
# 2020-08-03 05:00:00+00:00     499      True  3272.0  3275.6  3270.0  3272.4
# 2020-08-03 06:00:00+00:00     743      True  3272.0  3272.8  3267.3  3270.0
# 2020-08-03 07:00:00+00:00    1717      True  3270.3  3272.3  3263.0  3272.0
# 2020-08-03 08:00:00+00:00    1160      True  3272.3  3275.9  3264.3  3267.8
# 2020-08-03 09:00:00+00:00    1085      True  3267.5  3275.3  3266.0  3275.0
# 2020-08-03 10:00:00+00:00    1078      True  3274.5  3288.8  3273.8  3288.0
# 2020-08-03 11:00:00+00:00     697      True  3288.3  3292.0  3286.2  3291.8
# 2020-08-03 12:00:00+00:00     596      True  3292.3  3294.1  3290.3  3292.5
# 2020-08-03 13:00:00+00:00    1555      True  3292.6  3293.3  3284.7  3291.0
# 2020-08-03 14:00:00+00:00    1824      True  3290.8  3300.0  3286.5  3289.7
# 2020-08-03 15:00:00+00:00     753      True  3290.0  3301.5  3289.2  3298.2
# 2020-08-03 16:00:00+00:00     633      True  3298.5  3299.5  3295.0  3296.5
# 2020-08-03 17:00:00+00:00     566      True  3297.0  3300.0  3296.2  3298.5
# 2020-08-03 18:00:00+00:00     845      True  3298.8  3303.5  3296.7  3302.2
# 2020-08-03 19:00:00+00:00    1796      True  3302.5  3303.1  3291.5  3295.2
# 2020-08-03 20:00:00+00:00     643      True  3295.0  3298.6  3291.2  3297.0
# 2020-08-03 22:00:00+00:00     478      True  3295.8  3296.6  3293.8  3295.3
# 2020-08-03 23:00:00+00:00     409      True  3295.0  3298.4  3294.3  3295.8

# %% [markdown]
# ## Streaming high-frequency real-time Data

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
#stop param - max nr of ticks
api.stream_data('EUR_USD', stop = 20)
# Out:
# 2022-09-23T10:28:43.371902573Z 0.9766 0.9767
# 2022-09-23T10:28:43.547645423Z 0.9766 0.9767
# 2022-09-23T10:28:44.370266332Z 0.97658 0.97669
# 2022-09-23T10:28:44.493951279Z 0.97656 0.97668
# 2022-09-23T10:28:45.966605059Z 0.97652 0.97663
# 2022-09-23T10:28:46.572299787Z 0.97652 0.97662
# 2022-09-23T10:28:46.634825502Z 0.97651 0.97663
# 2022-09-23T10:28:48.059690148Z 0.9765 0.97661
# 2022-09-23T10:28:49.870259029Z 0.97651 0.97663
# 2022-09-23T10:28:51.707901789Z 0.97651 0.97663
# 2022-09-23T10:28:52.987265701Z 0.97651 0.97662
# 2022-09-23T10:28:53.274304784Z 0.97648 0.9766
# 2022-09-23T10:28:53.404175977Z 0.97649 0.97659
# 2022-09-23T10:28:53.828027072Z 0.97652 0.97663
# 2022-09-23T10:28:54.867648303Z 0.97653 0.97665
# 2022-09-23T10:28:54.975910719Z 0.97658 0.97669
# 2022-09-23T10:28:55.691395517Z 0.97658 0.97669
# 2022-09-23T10:28:55.802582654Z 0.97656 0.97668
# 2022-09-23T10:28:56.064539542Z 0.97657 0.97667
# 2022-09-23T10:28:56.313838290Z 0.97657 0.97668

# %%
api.stop_stream()

# %% [markdown]
# ## Creating Orders and Executing Trades

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.create_order(instrument = "EUR_USD", units = 100000, sl_distance= 0.1)
# Out:
#  {'id': '21', 'time': '2022-09-23T10:45:43.522040540Z', 'userID': 23109564, 'accountID': '101-012-23109564-001', 'batchID': '20', 'requestID': '43007825038017248', 'type': 'ORDER_FILL', 'orderID': '20', 'instrument': 'EUR_USD', 'units': '100000.0', 'gainQuoteHomeConversionFactor': '1.018929568454', 'lossQuoteHomeConversionFactor': '1.029170066629', 'price': 0.97658, 'fullVWAP': 0.97658, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 0.97645, 'liquidity': '1000000'}, {'price': 0.97644, 'liquidity': '2000000'}, {'price': 0.97643, 'liquidity': '2000000'}, {'price': 0.97641, 'liquidity': '5000000'}], 'asks': [{'price': 0.97658, 'liquidity': '1000000'}, {'price': 0.9766, 'liquidity': '2000000'}, {'price': 0.97661, 'liquidity': '2000000'}, {'price': 0.97662, 'liquidity': '5000000'}], 'closeoutBid': 0.97641, 'closeoutAsk': 0.97662}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '51084.9692', 'tradeOpened': {'tradeID': '21', 'units': '100000.0', 'price': 0.97658, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '6.6563', 'initialMarginRequired': '3330.0'}, 'halfSpreadCost': '6.6563'}

# %%
api.create_order(instrument = "EUR_USD", units = -100000, sl_distance= 0.1)
# Out:
#  {'id': '24', 'time': '2022-09-23T10:53:58.218807836Z', 'userID': 23109564, 'accountID': '101-012-23109564-001', 'batchID': '23', 'requestID': '79036624133296295', 'type': 'ORDER_FILL', 'orderID': '23', 'instrument': 'EUR_USD', 'units': '-100000.0', 'gainQuoteHomeConversionFactor': '1.019697069717', 'lossQuoteHomeConversionFactor': '1.029945281473', 'price': 0.97572, 'fullVWAP': 0.97572, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 0.97572, 'liquidity': '1000000'}, {'price': 0.97571, 'liquidity': '2000000'}, {'price': 0.9757, 'liquidity': '2000000'}, {'price': 0.97568, 'liquidity': '5000000'}], 'asks': [{'price': 0.97584, 'liquidity': '1000000'}, {'price': 0.97586, 'liquidity': '2000000'}, {'price': 0.97587, 'liquidity': '2000000'}, {'price': 0.97588, 'liquidity': '5000000'}], 'closeoutBid': 0.97568, 'closeoutAsk': 0.97588}, 'reason': 'MARKET_ORDER', 'pl': '-88.5753', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '50996.3939', 'tradesClosed': [{'tradeID': '21', 'units': '-100000.0', 'price': 0.97572, 'realizedPL': '-88.5753', 'financing': '0.0', 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '6.1489'}], 'halfSpreadCost': '6.1489'}

# %%
api.create_order(instrument = "EUR_USD", units = -100000, sl_distance= 0.1)

# %%
# api.get_account_summary()

# %%
api.get_transactions(tid = 0)
# api.get_transactions() tid - transaction id
# Out:
# [{'id': '1',
#   'time': '2022-08-29T12:03:45.377934162Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '1',
#   'requestID': '1754366643380400576',
#   'type': 'CREATE',
#   'divisionID': 12,
#   'siteID': 101,
#   'accountUserID': 23109564,
#   'accountNumber': 1,
#   'homeCurrency': 'EUR'},
#  {'id': '2',
#   'time': '2022-08-29T12:03:45.377934162Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '1',
#   'requestID': '1754366643380400576',
#   'type': 'CLIENT_CONFIGURE',
#   'alias': 'Primary',
#   'marginRate': '0.02'},
#  {'id': '3',
#   'time': '2022-08-29T12:03:45.996973030Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '3',
#   'requestID': '1772381041889874396',
#   'type': 'TRANSFER_FUNDS',
#   'amount': '100000.0',
#   'fundingReason': 'CLIENT_FUNDING',
#   'accountBalance': '100000.0'},
#  {'id': '4',
#   'time': '2022-08-29T12:10:44.198562009Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '4',
#   'requestID': '1772381043647346073',
#   'type': 'TRANSFER_FUNDS',
#   'amount': '-50000.0',
#   'fundingReason': 'ADJUSTMENT',
#   'accountBalance': '50000.0'},
#  {'id': '5',
#   'time': '2022-08-29T13:45:48.315514397Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '5',
#   'requestID': '24984412150140099',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '10000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER'},
#  {'id': '6',
#   'time': '2022-08-29T13:45:48.315514397Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '5',
#   'requestID': '24984412150140099',
#   'type': 'ORDER_FILL',
#   'orderID': '5',
#   'instrument': 'EUR_USD',
#   'units': '10000.0',
#   'gainQuoteHomeConversionFactor': '0.994239414026',
#   'lossQuoteHomeConversionFactor': '1.004231769946',
#   'price': 1.00083,
#   'fullVWAP': 1.00083,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.0007, 'liquidity': '1000000'},
#     {'price': 1.00069, 'liquidity': '2000000'},
#     {'price': 1.00068, 'liquidity': '2000000'},
#     {'price': 1.00066, 'liquidity': '5000000'}],
#    'asks': [{'price': 1.00083, 'liquidity': '1000000'},
#     {'price': 1.00085, 'liquidity': '2000000'},
#     {'price': 1.00086, 'liquidity': '2000000'},
#     {'price': 1.00087, 'liquidity': '5000000'}],
#    'closeoutBid': 1.00066,
#    'closeoutAsk': 1.00087},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '50000.0',
#   'tradeOpened': {'tradeID': '6',
#    'units': '10000.0',
#    'price': 1.00083,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '0.6495',
#    'initialMarginRequired': '333.0'},
#   'halfSpreadCost': '0.6495'},
#  {'id': '7',
#   'time': '2022-08-29T13:54:07.645306716Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '7',
#   'requestID': '61013211262209949',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-10000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'REDUCE_ONLY',
#   'tradeClose': {'tradeID': '6', 'units': '10000'},
#   'reason': 'TRADE_CLOSE'},
#  {'id': '8',
#   'time': '2022-08-29T13:54:07.645306716Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '7',
#   'requestID': '61013211262209949',
#   'type': 'ORDER_FILL',
#   'orderID': '7',
#   'instrument': 'EUR_USD',
#   'units': '-10000.0',
#   'gainQuoteHomeConversionFactor': '0.993648642708',
#   'lossQuoteHomeConversionFactor': '1.003635061228',
#   'price': 1.00131,
#   'fullVWAP': 1.00131,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.00131, 'liquidity': '1000000'},
#     {'price': 1.0013, 'liquidity': '2000000'},
#     {'price': 1.00129, 'liquidity': '2000000'},
#     {'price': 1.00127, 'liquidity': '5000000'}],
#    'asks': [{'price': 1.00141, 'liquidity': '1000000'},
#     {'price': 1.00143, 'liquidity': '2000000'},
#     {'price': 1.00144, 'liquidity': '2000000'},
#     {'price': 1.00145, 'liquidity': '5000000'}],
#    'closeoutBid': 1.00127,
#    'closeoutAsk': 1.00145},
#   'reason': 'MARKET_ORDER_TRADE_CLOSE',
#   'pl': '4.7695',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '50004.7695',
#   'tradesClosed': [{'tradeID': '6',
#     'units': '-10000.0',
#     'price': 1.00131,
#     'realizedPL': '4.7695',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '0.4993'}],
#   'halfSpreadCost': '0.4993'},
#  {'id': '9',
#   'time': '2022-09-02T10:39:47.562642758Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '9',
#   'requestID': '79029010417646826',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_JPY',
#   'units': '50000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'takeProfitOnFill': {'price': 143.444, 'timeInForce': 'GTC'},
#   'stopLossOnFill': {'price': 138.222, 'timeInForce': 'GTC'}},
#  {'id': '10',
#   'time': '2022-09-02T10:39:47.562642758Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '9',
#   'requestID': '79029010417646826',
#   'type': 'ORDER_FILL',
#   'orderID': '9',
#   'instrument': 'EUR_JPY',
#   'units': '50000.0',
#   'gainQuoteHomeConversionFactor': '0.00709149096',
#   'lossQuoteHomeConversionFactor': '0.007162762226',
#   'price': 140.319,
#   'fullVWAP': 140.319,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 140.299, 'liquidity': '10000000'}],
#    'asks': [{'price': 140.319, 'liquidity': '10000000'}],
#    'closeoutBid': 140.299,
#    'closeoutAsk': 140.319},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '50004.7695',
#   'tradeOpened': {'tradeID': '10',
#    'units': '50000.0',
#    'price': 140.319,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '3.5636',
#    'initialMarginRequired': '1665.0'},
#   'halfSpreadCost': '3.5636'},
#  {'id': '11',
#   'time': '2022-09-02T10:39:47.562642758Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '9',
#   'requestID': '79029010417646826',
#   'type': 'TAKE_PROFIT_ORDER',
#   'tradeID': '10',
#   'price': 143.444,
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '12',
#   'time': '2022-09-02T10:39:47.562642758Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '9',
#   'requestID': '79029010417646826',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '10',
#   'price': 138.222,
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '13',
#   'time': '2022-09-02T21:00:00.000000000Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '13',
#   'type': 'DAILY_FINANCING',
#   'financing': '-1.274',
#   'accountBalance': '50003.4955',
#   'positionFinancings': [{'instrument': 'EUR_JPY',
#     'financing': '-1.274',
#     'openTradeFinancings': [{'tradeID': '10', 'financing': '-1.274'}]}]},
#  {'id': '14',
#   'time': '2022-09-03T21:00:00.000000000Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '14',
#   'type': 'DAILY_FINANCING',
#   'financing': '0.0',
#   'accountBalance': '50003.4955',
#   'positionFinancings': [{'instrument': 'EUR_JPY',
#     'financing': '0.0',
#     'openTradeFinancings': [{'tradeID': '10', 'financing': '0.0'}]}]},
#  {'id': '15',
#   'time': '2022-09-04T21:00:00.000000000Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '15',
#   'type': 'DAILY_FINANCING',
#   'financing': '0.0',
#   'accountBalance': '50003.4955',
#   'positionFinancings': [{'instrument': 'EUR_JPY',
#     'financing': '0.0',
#     'openTradeFinancings': [{'tradeID': '10', 'financing': '0.0'}]}]},
#  {'id': '16',
#   'time': '2022-09-05T21:00:00.000000000Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '16',
#   'type': 'DAILY_FINANCING',
#   'financing': '-1.3288',
#   'accountBalance': '50002.1667',
#   'positionFinancings': [{'instrument': 'EUR_JPY',
#     'financing': '-1.3288',
#     'openTradeFinancings': [{'tradeID': '10', 'financing': '-1.3288'}]}]},
#  {'id': '17',
#   'time': '2022-09-06T21:00:00.000000000Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '17',
#   'type': 'DAILY_FINANCING',
#   'financing': '-1.3014',
#   'accountBalance': '50000.8653',
#   'positionFinancings': [{'instrument': 'EUR_JPY',
#     'financing': '-1.3014',
#     'openTradeFinancings': [{'tradeID': '10', 'financing': '-1.3014'}]}]},
#  {'id': '18',
#   'time': '2022-09-07T13:31:35.462507061Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '18',
#   'type': 'ORDER_FILL',
#   'orderID': '11',
#   'instrument': 'EUR_JPY',
#   'units': '-50000.0',
#   'gainQuoteHomeConversionFactor': '0.006936045503',
#   'lossQuoteHomeConversionFactor': '0.007005754503',
#   'price': 143.445,
#   'fullVWAP': 143.445,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 143.445, 'liquidity': '10000000'}],
#    'asks': [{'price': 143.462, 'liquidity': '10000000'}],
#    'closeoutBid': 143.445,
#    'closeoutAsk': 143.462},
#   'reason': 'TAKE_PROFIT_ORDER',
#   'pl': '1084.1039',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '51084.9692',
#   'tradesClosed': [{'tradeID': '10',
#     'units': '-50000.0',
#     'price': 143.445,
#     'realizedPL': '1084.1039',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '2.9626'}],
#   'halfSpreadCost': '2.9626'},
#  {'id': '19',
#   'time': '2022-09-07T13:31:35.462507061Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '18',
#   'type': 'ORDER_CANCEL',
#   'orderID': '12',
#   'reason': 'LINKED_TRADE_CLOSED'},
#  {'id': '20',
#   'time': '2022-09-23T10:45:43.522040540Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '20',
#   'requestID': '43007825038017248',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '100000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '21',
#   'time': '2022-09-23T10:45:43.522040540Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '20',
#   'requestID': '43007825038017248',
#   'type': 'ORDER_FILL',
#   'orderID': '20',
#   'instrument': 'EUR_USD',
#   'units': '100000.0',
#   'gainQuoteHomeConversionFactor': '1.018929568454',
#   'lossQuoteHomeConversionFactor': '1.029170066629',
#   'price': 0.97658,
#   'fullVWAP': 0.97658,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 0.97645, 'liquidity': '1000000'},
#     {'price': 0.97644, 'liquidity': '2000000'},
#     {'price': 0.97643, 'liquidity': '2000000'},
#     {'price': 0.97641, 'liquidity': '5000000'}],
#    'asks': [{'price': 0.97658, 'liquidity': '1000000'},
#     {'price': 0.9766, 'liquidity': '2000000'},
#     {'price': 0.97661, 'liquidity': '2000000'},
#     {'price': 0.97662, 'liquidity': '5000000'}],
#    'closeoutBid': 0.97641,
#    'closeoutAsk': 0.97662},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '51084.9692',
#   'tradeOpened': {'tradeID': '21',
#    'units': '100000.0',
#    'price': 0.97658,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '6.6563',
#    'initialMarginRequired': '3330.0'},
#   'halfSpreadCost': '6.6563'},
#  {'id': '22',
#   'time': '2022-09-23T10:45:43.522040540Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '20',
#   'requestID': '43007825038017248',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '21',
#   'price': 0.87658,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '23',
#   'time': '2022-09-23T10:53:58.218807836Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '23',
#   'requestID': '79036624133296295',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-100000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '24',
#   'time': '2022-09-23T10:53:58.218807836Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '23',
#   'requestID': '79036624133296295',
#   'type': 'ORDER_FILL',
#   'orderID': '23',
#   'instrument': 'EUR_USD',
#   'units': '-100000.0',
#   'gainQuoteHomeConversionFactor': '1.019697069717',
#   'lossQuoteHomeConversionFactor': '1.029945281473',
#   'price': 0.97572,
#   'fullVWAP': 0.97572,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 0.97572, 'liquidity': '1000000'},
#     {'price': 0.97571, 'liquidity': '2000000'},
#     {'price': 0.9757, 'liquidity': '2000000'},
#     {'price': 0.97568, 'liquidity': '5000000'}],
#    'asks': [{'price': 0.97584, 'liquidity': '1000000'},
#     {'price': 0.97586, 'liquidity': '2000000'},
#     {'price': 0.97587, 'liquidity': '2000000'},
#     {'price': 0.97588, 'liquidity': '5000000'}],
#    'closeoutBid': 0.97568,
#    'closeoutAsk': 0.97588},
#   'reason': 'MARKET_ORDER',
#   'pl': '-88.5753',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '50996.3939',
#   'tradesClosed': [{'tradeID': '21',
#     'units': '-100000.0',
#     'price': 0.97572,
#     'realizedPL': '-88.5753',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '6.1489'}],
#   'halfSpreadCost': '6.1489'},
#  {'id': '25',
#   'time': '2022-09-23T10:53:58.218807836Z',
#   'userID': 23109564,
#   'accountID': '101-012-23109564-001',
#   'batchID': '23',
#   'requestID': '79036624133296295',
#   'type': 'ORDER_CANCEL',
#   'orderID': '22',
#   'reason': 'LINKED_TRADE_CLOSED'}]

# %%
api.print_transactions(tid = 0)
# Out:
#     6 | 2022-08-29T13:45:48.315514397Z |   EUR_USD |      10000.0 |      0.0
#     8 | 2022-08-29T13:54:07.645306716Z |   EUR_USD |     -10000.0 |   4.7695
#    10 | 2022-09-02T10:39:47.562642758Z |   EUR_JPY |      50000.0 |      0.0
#    18 | 2022-09-07T13:31:35.462507061Z |   EUR_JPY |     -50000.0 | 1084.1039
#    21 | 2022-09-23T10:45:43.522040540Z |   EUR_USD |     100000.0 |      0.0
#    24 | 2022-09-23T10:53:58.218807836Z |   EUR_USD |    -100000.0 | -88.5753

# %%
#SHORT POSITION
#OPEN POSITION
api.create_order(instrument = "EUR_USD", units = -50000, sl_distance= 0.1)
# Out:
#  {'id': '27', 'time': '2022-09-23T11:01:32.962046654Z', 'userID': 23109564, 'accountID': '101-012-23109564-001', 'batchID': '26', 'requestID': '43007829015693465', 'type': 'ORDER_FILL', 'orderID': '26', 'instrument': 'EUR_USD', 'units': '-50000.0', 'gainQuoteHomeConversionFactor': '1.019791129036', 'lossQuoteHomeConversionFactor': '1.030040286112', 'price': 0.97563, 'fullVWAP': 0.97563, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 0.97563, 'liquidity': '1000000'}, {'price': 0.97562, 'liquidity': '2000000'}, {'price': 0.97561, 'liquidity': '2000000'}, {'price': 0.97559, 'liquidity': '5000000'}], 'asks': [{'price': 0.97575, 'liquidity': '1000000'}, {'price': 0.97577, 'liquidity': '2000000'}, {'price': 0.97578, 'liquidity': '2000000'}, {'price': 0.97579, 'liquidity': '5000000'}], 'closeoutBid': 0.97559, 'closeoutAsk': 0.97579}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '50996.3939', 'tradeOpened': {'tradeID': '27', 'units': '-50000.0', 'price': 0.97563, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '3.0747', 'initialMarginRequired': '1665.0'}, 'halfSpreadCost': '3.0747'}

# %%
#CLOSE POSITION
api.create_order(instrument = "EUR_USD", units = 50000, sl_distance= 0.1)
# Out:
#  {'id': '30', 'time': '2022-09-23T11:03:13.358248838Z', 'userID': 23109564, 'accountID': '101-012-23109564-001', 'batchID': '29', 'requestID': '43007829439481267', 'type': 'ORDER_FILL', 'orderID': '29', 'instrument': 'EUR_USD', 'units': '50000.0', 'gainQuoteHomeConversionFactor': '1.019994982938', 'lossQuoteHomeConversionFactor': '1.030246188797', 'price': 0.97555, 'fullVWAP': 0.97555, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 0.97544, 'liquidity': '1000000'}, {'price': 0.97543, 'liquidity': '2000000'}, {'price': 0.97542, 'liquidity': '2000000'}, {'price': 0.9754, 'liquidity': '5000000'}], 'asks': [{'price': 0.97555, 'liquidity': '1000000'}, {'price': 0.97557, 'liquidity': '2000000'}, {'price': 0.97558, 'liquidity': '2000000'}, {'price': 0.97559, 'liquidity': '5000000'}], 'closeoutBid': 0.9754, 'closeoutAsk': 0.97559}, 'reason': 'MARKET_ORDER', 'pl': '4.08', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '51000.4739', 'tradesClosed': [{'tradeID': '27', 'units': '50000.0', 'price': 0.97555, 'realizedPL': '4.08', 'financing': '0.0', 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '2.8191'}], 'halfSpreadCost': '2.8191'}
